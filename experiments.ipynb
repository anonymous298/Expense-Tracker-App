# %%
import pandas as pd

# %%
data = {
    'expense_name' : ['sushi', 'biryani', 'rent'],
    'price' : [1000, 500, 50000] 
}

# %%
df = pd.DataFrame(data=data)

# %%
df.to_csv('expenses.csv', index=False)

# %%
df.head()
# Out:
#       name category  expense
# 0    sushi     food     1000
# 1  biryani     food      500
# 2     rent     home    50000

# %%
new_row = pd.DataFrame({'name' : ['trip'], 'category' : ['home'], 'expense' : ['100000']})

# %%
pd.concat([df, new_row], axis=0)
# Out:
#       name category expense
# 0    sushi     food    1000
# 1  biryani     food     500
# 2     rent     home   50000
# 0     trip     home  100000

# %%
df = pd.read_csv('expenses.csv')

# %%
df.head()
# Out:
#   expense_name  price
# 0        sushi   1000
# 1      biryani    500
# 2         rent  50000
# 3      clothes   5000
